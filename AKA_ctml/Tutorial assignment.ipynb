# %% [markdown]
# Python Programming Tutorial

# %% [markdown]
# Python is a "jack of all trades" programming language. It can be applied in various functions and can be used to solve different problems. It is also easy to write and interprete.

# %% [markdown]
# Data types in Python

# %% [markdown]
# Integer

# %%
# whole numbers,either positive or negative,with no decimal. E.g: 8

# %% [markdown]
# Float

# %%
# numbers with a decimal point. E.g : 1.5

# %% [markdown]
# String

# %%
# sequence of characters enclosed in single or double quotes. E.g: 'Angie loves coding'

# %% [markdown]
# Boolean

# %%
# one of two values. E.g: true or false

# %% [markdown]
# Variables: Variables store data values (could be in the form of any data type).

# %%
x = 8

# %%
print(x)
# Out:
# 8

# %%
# x is a variable, storing the integer: 8

# %%
y = 'Angie loves coding'

# %%
print(y)
# Out:
# Angie loves coding

# %% [markdown]
# Arithmetic operations

# %% [markdown]
# Python can also be used for some simple arithmetic operations such as additions, divisions, multiplications and subtractions.

# %%
a = 8

# %%
b = 1.5

# %%
print(a+b)
# Out:
# 9.5

# %%
print(a-b)
# Out:
# 6.5

# %%
print(a/b)
# Out:
# 5.333333333333333

# %%
print(a*b)
# Out:
# 12.0

# %%
# Above are examples of applications in all the four listed arithmetic operations

# %% [markdown]
# Next up, we will look at Object-oriented programming in the context of Python.
#
# to be continued....
